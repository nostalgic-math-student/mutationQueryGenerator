# %%
from collections import defaultdict

# Assuming each area now includes 'Rows' and 'indexLabel' for demonstration
## TO DO: Change format of Rows from :[[301,304],[301,306]] ---> {length: [301,306], numRows: 2}
areas = [
    {
        "id": "01",
        "title": "General Admission",
        "name": "General Admission",
        "total":300,
    },
    {
        "id": "02",
        "title": "VIP Admission",
        "name": "VIP Admission",
        "total":300,
    },
]
    # {
    #     "Reversed": True,
    #     "id": "01",
    #     "title": "General Plus Admission",
    #     "name": "General Plus Admission",
    #     "total":1300,
    # },
    # {
    #     "Reversed": True,
    #     "id": "01",
    #     "title": "General VIP Admission",
    #     "name": "General VIP Admission",
    #     "total":1000,
    # },
    # {
    #     "Reversed": True,
    #     "id": "01",
    #     "title": "Deluxe Admission",
    #     "name": "Deluxe Admission",
    #     "total":1000,
    # },


prices_and_fees = {
    "General Admission": {"price": "19.99", "fees": "7.44"},
    "VIP Admission": {"price": "29.99", "fees": "8.57"},
}

# %%
grouped_areas = defaultdict(list)
for area in areas:
    grouped_areas[area["name"]].append(area)

# %%
for zone_name, areas in grouped_areas.items():
    print(zone_name)
    for area in areas:
        print(area['total'])
        print(range(area['total']))
# Out:
# General Admission
# 300
# range(0, 300)
# VIP Admission
# 300
# range(0, 300)

# %%
def generate_seat_data(area, seat):
    seat_str = "Ticket for "
    seat_str = seat_str +  area + " " + "no. " + str(seat) 
    return seat_str

# %%
title = "Cinco de Mayo - La Original Banda El Limón de Salvador Lizárraga"
description = "Cinco de Mayo show featuring La Original Banda el Limón de Salvador Lizárraga at Clayton's South Padre Island. "

def generate_gql_mutation_with_seats(grouped_areas, prices_and_fees):
    mutation = ["mutation CreateEvent {"]
    mutation.append("  createEvent(")
    mutation.append("    data: {")
    mutation.append('      description: "Soundtrack de la Naranja Mecanica en vivo.",')
    mutation.append('      name: "La Naranja Mecanica",')
    mutation.append("      eventZones: {")
    mutation.append("        create: [")

    for zone_name, areas in grouped_areas.items():
        mutation.append(
            f'          {{ name: "{zone_name}", fees: "{prices_and_fees[zone_name]["fees"]}", price: "{prices_and_fees[zone_name]["price"]}", eventZoneRows: {{ create: ['
        )
        for area in areas:
            seats_str = ""
            
            for seat_index in range(1,area['total'] + 1):
                seat_data = generate_seat_data(zone_name, seat_index)
                seats_str = seats_str +", " + '{{ name: "{0}", subZoneTag: "{1}" }}'.format(seat_data, seat_index) 
            print("seat data", seats_str)
            mutation.append(
                f'                {{ name: "{area["title"]}", eventSeats: {{ create: [{seats_str}] }} }},'
                )
        mutation.append("              ] } },")

    mutation.append("        ]")
    mutation.append("      }")
    mutation.append("    }")
    mutation.append("  ) {")
    mutation.append("    id")
    mutation.append("  }")
    mutation.append("}")

    return "\n".join(mutation)

# Generate the mutation string with variable prices, fees, dynamically generated seat names, and subZoneTags
corrected_mutation_str_with_subzone = generate_gql_mutation_with_seats(
    grouped_areas, prices_and_fees
)
# Out:
# seat data , { name: "Ticket for General Admission no. 1", subZoneTag: "1" }, { name: "Ticket for General Admission no. 2", subZoneTag: "2" }, { name: "Ticket for General Admission no. 3", subZoneTag: "3" }, { name: "Ticket for General Admission no. 4", subZoneTag: "4" }, { name: "Ticket for General Admission no. 5", subZoneTag: "5" }, { name: "Ticket for General Admission no. 6", subZoneTag: "6" }, { name: "Ticket for General Admission no. 7", subZoneTag: "7" }, { name: "Ticket for General Admission no. 8", subZoneTag: "8" }, { name: "Ticket for General Admission no. 9", subZoneTag: "9" }, { name: "Ticket for General Admission no. 10", subZoneTag: "10" }, { name: "Ticket for General Admission no. 11", subZoneTag: "11" }, { name: "Ticket for General Admission no. 12", subZoneTag: "12" }, { name: "Ticket for General Admission no. 13", subZoneTag: "13" }, { name: "Ticket for General Admission no. 14", subZoneTag: "14" }, { name: "Ticket for General Admission no. 15", subZoneTag: "15" }, { name: "Ticket for General Admission no. 16", subZoneTag: "16" }, { name: "Ticket for General Admission no. 17", subZoneTag: "17" }, { name: "Ticket for General Admission no. 18", subZoneTag: "18" }, { name: "Ticket for General Admission no. 19", subZoneTag: "19" }, { name: "Ticket for General Admission no. 20", subZoneTag: "20" }, { name: "Ticket for General Admission no. 21", subZoneTag: "21" }, { name: "Ticket for General Admission no. 22", subZoneTag: "22" }, { name: "Ticket for General Admission no. 23", subZoneTag: "23" }, { name: "Ticket for General Admission no. 24", subZoneTag: "24" }, { name: "Ticket for General Admission no. 25", subZoneTag: "25" }, { name: "Ticket for General Admission no. 26", subZoneTag: "26" }, { name: "Ticket for General Admission no. 27", subZoneTag: "27" }, { name: "Ticket for General Admission no. 28", subZoneTag: "28" }, { name: "Ticket for General Admission no. 29", subZoneTag: "29" }, { name: "Ticket for General Admission no. 30", subZoneTag: "30" }, { name: "Ticket for General Admission no. 31", subZoneTag: "31" }, { name: "Ticket for General Admission no. 32", subZoneTag: "32" }, { name: "Ticket for General Admission no. 33", subZoneTag: "33" }, { name: "Ticket for General Admission no. 34", subZoneTag: "34" }, { name: "Ticket for General Admission no. 35", subZoneTag: "35" }, { name: "Ticket for General Admission no. 36", subZoneTag: "36" }, { name: "Ticket for General Admission no. 37", subZoneTag: "37" }, { name: "Ticket for General Admission no. 38", subZoneTag: "38" }, { name: "Ticket for General Admission no. 39", subZoneTag: "39" }, { name: "Ticket for General Admission no. 40", subZoneTag: "40" }, { name: "Ticket for General Admission no. 41", subZoneTag: "41" }, { name: "Ticket for General Admission no. 42", subZoneTag: "42" }, { name: "Ticket for General Admission no. 43", subZoneTag: "43" }, { name: "Ticket for General Admission no. 44", subZoneTag: "44" }, { name: "Ticket for General Admission no. 45", subZoneTag: "45" }, { name: "Ticket for General Admission no. 46", subZoneTag: "46" }, { name: "Ticket for General Admission no. 47", subZoneTag: "47" }, { name: "Ticket for General Admission no. 48", subZoneTag: "48" }, { name: "Ticket for General Admission no. 49", subZoneTag: "49" }, { name: "Ticket for General Admission no. 50", subZoneTag: "50" }, { name: "Ticket for General Admission no. 51", subZoneTag: "51" }, { name: "Ticket for General Admission no. 52", subZoneTag: "52" }, { name: "Ticket for General Admission no. 53", subZoneTag: "53" }, { name: "Ticket for General Admission no. 54", subZoneTag: "54" }, { name: "Ticket for General Admission no. 55", subZoneTag: "55" }, { name: "Ticket for General Admission no. 56", subZoneTag: "56" }, { name: "Ticket for General Admission no. 57", subZoneTag: "57" }, { name: "Ticket for General Admission no. 58", subZoneTag: "58" }, { name: "Ticket for General Admission no. 59", subZoneTag: "59" }, { name: "Ticket for General Admission no. 60", subZon ...
# seat data , { name: "Ticket for VIP Admission no. 1", subZoneTag: "1" }, { name: "Ticket for VIP Admission no. 2", subZoneTag: "2" }, { name: "Ticket for VIP Admission no. 3", subZoneTag: "3" }, { name: "Ticket for VIP Admission no. 4", subZoneTag: "4" }, { name: "Ticket for VIP Admission no. 5", subZoneTag: "5" }, { name: "Ticket for VIP Admission no. 6", subZoneTag: "6" }, { name: "Ticket for VIP Admission no. 7", subZoneTag: "7" }, { name: "Ticket for VIP Admission no. 8", subZoneTag: "8" }, { name: "Ticket for VIP Admission no. 9", subZoneTag: "9" }, { name: "Ticket for VIP Admission no. 10", subZoneTag: "10" }, { name: "Ticket for VIP Admission no. 11", subZoneTag: "11" }, { name: "Ticket for VIP Admission no. 12", subZoneTag: "12" }, { name: "Ticket for VIP Admission no. 13", subZoneTag: "13" }, { name: "Ticket for VIP Admission no. 14", subZoneTag: "14" }, { name: "Ticket for VIP Admission no. 15", subZoneTag: "15" }, { name: "Ticket for VIP Admission no. 16", subZoneTag: "16" }, { name: "Ticket for VIP Admission no. 17", subZoneTag: "17" }, { name: "Ticket for VIP Admission no. 18", subZoneTag: "18" }, { name: "Ticket for VIP Admission no. 19", subZoneTag: "19" }, { name: "Ticket for VIP Admission no. 20", subZoneTag: "20" }, { name: "Ticket for VIP Admission no. 21", subZoneTag: "21" }, { name: "Ticket for VIP Admission no. 22", subZoneTag: "22" }, { name: "Ticket for VIP Admission no. 23", subZoneTag: "23" }, { name: "Ticket for VIP Admission no. 24", subZoneTag: "24" }, { name: "Ticket for VIP Admission no. 25", subZoneTag: "25" }, { name: "Ticket for VIP Admission no. 26", subZoneTag: "26" }, { name: "Ticket for VIP Admission no. 27", subZoneTag: "27" }, { name: "Ticket for VIP Admission no. 28", subZoneTag: "28" }, { name: "Ticket for VIP Admission no. 29", subZoneTag: "29" }, { name: "Ticket for VIP Admission no. 30", subZoneTag: "30" }, { name: "Ticket for VIP Admission no. 31", subZoneTag: "31" }, { name: "Ticket for VIP Admission no. 32", subZoneTag: "32" }, { name: "Ticket for VIP Admission no. 33", subZoneTag: "33" }, { name: "Ticket for VIP Admission no. 34", subZoneTag: "34" }, { name: "Ticket for VIP Admission no. 35", subZoneTag: "35" }, { name: "Ticket for VIP Admission no. 36", subZoneTag: "36" }, { name: "Ticket for VIP Admission no. 37", subZoneTag: "37" }, { name: "Ticket for VIP Admission no. 38", subZoneTag: "38" }, { name: "Ticket for VIP Admission no. 39", subZoneTag: "39" }, { name: "Ticket for VIP Admission no. 40", subZoneTag: "40" }, { name: "Ticket for VIP Admission no. 41", subZoneTag: "41" }, { name: "Ticket for VIP Admission no. 42", subZoneTag: "42" }, { name: "Ticket for VIP Admission no. 43", subZoneTag: "43" }, { name: "Ticket for VIP Admission no. 44", subZoneTag: "44" }, { name: "Ticket for VIP Admission no. 45", subZoneTag: "45" }, { name: "Ticket for VIP Admission no. 46", subZoneTag: "46" }, { name: "Ticket for VIP Admission no. 47", subZoneTag: "47" }, { name: "Ticket for VIP Admission no. 48", subZoneTag: "48" }, { name: "Ticket for VIP Admission no. 49", subZoneTag: "49" }, { name: "Ticket for VIP Admission no. 50", subZoneTag: "50" }, { name: "Ticket for VIP Admission no. 51", subZoneTag: "51" }, { name: "Ticket for VIP Admission no. 52", subZoneTag: "52" }, { name: "Ticket for VIP Admission no. 53", subZoneTag: "53" }, { name: "Ticket for VIP Admission no. 54", subZoneTag: "54" }, { name: "Ticket for VIP Admission no. 55", subZoneTag: "55" }, { name: "Ticket for VIP Admission no. 56", subZoneTag: "56" }, { name: "Ticket for VIP Admission no. 57", subZoneTag: "57" }, { name: "Ticket for VIP Admission no. 58", subZoneTag: "58" }, { name: "Ticket for VIP Admission no. 59", subZoneTag: "59" }, { name: "Ticket for VIP Admission no. 60", subZoneTag: "60" }, { name: "Ticket for VIP Admission no. 61", subZoneTag: "61" }, { name: "Ticket for VIP Admission no. 62", subZoneTag: "62" }, { name: "Ticket for VIP Admission no. 63", subZoneTag: "63" }, { name: "Ticket for VIP Admission no. ...

# %%
corrected_file_path = "Notebook_corrected_gql_mutation_zones.txt"
with open(corrected_file_path, "w") as file:
    file.write(corrected_mutation_str_with_subzone)
